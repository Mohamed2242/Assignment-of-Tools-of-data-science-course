# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Mohamed Ahmed Mohamed Sayed.**
# <br>My desired occupation is: to be a data scientist<br>

# %% [markdown]
# *I am interested in data science because I like thinking in data sets and sheets and cleaning, analyzing, visualizing and making suitable model.
# I like thinking about a problem and trying to find the best solution of it.*

# %% [markdown]
# ### multiplying 2 by 10

# %%
2 * 10
# Out:
# 20

# %% [markdown]
# * I
# * Love
# * Data
# * Science
#
# 1. first statement
# 2. second statement
#
# [Click here to go to IBM](https://www.ibm.com)
